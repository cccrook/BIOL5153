# %%
#Chapter 3

#In python you have to open a file before you can read it

#To open a file:
my_file = open('dna.txt')

my_string = "abcdefg"
print(my_string)
my_number = 42
print(my_number + 1)

#When working with files most of your interactions will be through methods

#To read a file
my_file = open('dna.txt')
file_contents = my_file.read()
print(file_contents)

apple = 'dna.txt'
banana = open(apple)
grape = banana.read

#The read method only works on file objects
my_file_name = 'dna.txt'
my_contents = my_file_name.read


#Another common error is to use the file object when you meant to use the file contents
my_file_name = 'dna.txt'
my_file = open(my_file_name)
print(my_file)

#Dealing with newlines

#open the file
my_file = open('dna.txt')
#read the contents
my_dna = my_file.read()
#calculate the length
dna_length = len(my_dna)
#print the output
print('sequence is' + my_dna + str(dna_length))


#Stripping the newlines
my_file = open('dna.txt')
my_file_contents = my_file.read()
#remove the newline from the end of the file contents
my_dna = my_file_contents.rstrip('\n')
dna_length = len(my_dna)
print('sequence is' + my_dna + 'and length is' + str(dna_length))

#You can also read the contents and remove the newline in one step
my_dna = my_file.read().rstrip('\n')

#If you try to use a file that doesn't exist
my_file = open('nonexistant.txt')


#Opening and writing text to files

#write abcdef
my_file.write('abc' + 'def')
#arugments
    #r for reading
    #w for writing
    #a for appending

#closing files
my_file.close

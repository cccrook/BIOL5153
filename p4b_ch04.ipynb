# %%
#Chapter 4: Lists and Loops

#To make a list put several strings or numbers inside square brackets separated by commas
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
conserved_sites = [24, 56, 132]

#Each individual item in a list is called an element

#To get a single element from the list write the variable name followed by the index of the element you want in square brackets
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
conserved_sites = [24, 56, 132]
print(apes[0])
first_site = conserved_sites[2]

#If you know which element you want but don't know the index, use the index method
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
chimp_index = apes.index("Pan troglodytes")
# chimp_index is now 1

#If you give a negative number, Python will count from the end of the index
last_ape = apes[-1]

#You can give a start and stop position separated by a colon to specify a range of elements
ranks = ["Kingdom", "Phylum", "Class", "Order", "Family"]
lower_ranks = ranks[2:5]
#Lower ranks are class, order, and family

#To add another element onto the end of an existing list, use the append method
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
apes.append("Pan paniscus")

#You can use the length function to get the length of a list
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
print("There are " + str(len(apes)) + " apes")
apes.append("Pan paniscus")
print("Now there are " + str(len(apes)) + " apes")

#You can concatenate lists just like you can strings using the plus sign
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
monkeys = ["Papio ursinus", "Macaca mulatta"]
primates = apes + monkeys
print(str(len(apes) + " apes"))
print(str(len(monkeys) + " monkeys"))
print(str(len(primates) + " primates"))

#To add elements from a list onto the end of an existing list, use the extend method
#extend behaves like append but it takes a list as an argument rather than a single element
#The reverse and sort methods change the order of elements in a list
ranks = ["Kingdom", "Phylum", "Class", "Order", "Family"]
print("at the start : " + str(ranks))
ranks.reverse()
print("afer reversing : " + str(ranks))
ranks.sort()
print("after sorting : " + str(ranks))

#Python's loop syntax allows you to perform the same repetitive action on each element in a loop
for ape in apes:
    print(ape + " is an ape")
    
apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
for ape in apes:
    name_length = len(ape)
    first_letter = ape[0]
    print(ape + " is an ape")
    print("Its name has " + str(name_length) + " letters")
    
#apes = ["Homo sapiens", "Pan troglodytes", "Gorilla gorilla"]
#for ape in apes:
#    name_length = len(ape)
#   first_letter = ape[0]
#    print(ape + " is an ape")
#    print("Its name has " + str(name_length) + " letters")
    
#You can also use loop notation on a string
name = "martin"
for character in name:
    print("one character is " + character)
    
#The split method works on strings to produce a list
names = "melanogaster,simulans,yakuba,ananassae"
species = names.split(",")
print(str(species))

#You can use a file object as a list as well. Each line becomes an element in the list
file = open(some_input.txt)
for line in file:
    #do something with the line
    
#Loop over a list of numbers
protein = "vlspadktnv"
stop_positions = [3,4,5,6,7,8,9,10]
for stop in stop_position:
    substring = protein[0:stop]
    print(substring)
    
#Range function generates a list of numbers for you to loop over
for number in range(6):
    print(number)
    
#With two numbers, the range function will count from the 1st number to the 2nd
for number in range(3, 8):
    print(number)
    
#With three numbers it will count from 1st to 2nd in intervals of the 3rd
for number in range(2, 14, 4):
    print(number)
